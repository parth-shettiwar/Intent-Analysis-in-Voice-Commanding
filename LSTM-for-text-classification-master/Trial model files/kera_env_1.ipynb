# %%
import csv
import tensorflow as tf
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
import pickle

print(tf.__version__)
# Out:
# 1.14.0

# %%
df = pd.read_csv ('Dataset1.csv')
print (df)
# Out:
#                                         INTENT  ID Unnamed: 2
# 0                       Undo the last sentence   1        NaN
# 1                           Undo the last word   1        NaN
# 2               Can you undo the last sentence   1        NaN
# 3                         Please undo the text   1        NaN
# 4                       Undo the selected text   1        NaN
# ..                                         ...  ..        ...
# 423             Please delete all text in bold  26        NaN
# 424             Kindly delete all text in bold  26        NaN
# 425                   Erase the last paragraph  26        NaN
# 426  Erase the last two words of that sentence  26        NaN
# 427                      Please erase all text  26        NaN
#
# [428 rows x 3 columns]

# %%
  df_shuffled = df.sample(frac=1).reset_index(drop=True)

# %%
for index, row in df_shuffled.iterrows():

    tts_string=row['INTENT']
    tts_string=tts_string.lower() #lower case

    #lemmatize, then remove stopwords
    lemmatizer=WordNetLemmatizer()
    lemmatised_string=word_tokenize(tts_string)
    tts_string=""
    for word in lemmatised_string:
        tts_string=tts_string+lemmatizer.lemmatize(word)+" "
    tts_string=tts_string.strip()
    print(tts_string)

    #remove stopwords
    tokens = word_tokenize(tts_string)
    result = [i for i in tokens if not i in STOPWORDS]
    
    
    custom_stopwords = ['please','could','kindly']
    # using list comprehension to perform task 
    result = [i for i in result if i not in custom_stopwords] 


    print(result)
    
    preprocessed_str=""
#     print("here",preprocessed_str)
    for i in result:
        preprocessed_str=preprocessed_str+" "+i
#     preprocessed_str=' '.join(map(str, result))  
    print("Pre processed string",preprocessed_str)
    preprocessed_str=preprocessed_str.strip()
    # row['INTENT']=preprocessed_string

    #remove certain words
    #lemmatization
    #convert digits to numerals
    #text canonicalization?

    df_shuffled.at[index,'INTENT']=preprocessed_str
# Out:
# format to underline for me
# ['format', 'underline']
# Pre processed string  format underline
# please remove formatting
# ['remove', 'formatting']
# Pre processed string  remove formatting
# delete all the text in bold
# ['delete', 'text', 'bold']
# Pre processed string  delete text bold
# undo the selected text
# ['undo', 'selected', 'text']
# Pre processed string  undo selected text
# please format to underline that
# ['format', 'underline']
# Pre processed string  format underline
# please underline the selected text
# ['underline', 'selected', 'text']
# Pre processed string  underline selected text
# please insert comment
# ['insert', 'comment']
# Pre processed string  insert comment
# move this line to the right
# ['move', 'line', 'right']
# Pre processed string  move line right
# please centre-align first word of the paragraph
# ['centre-align', 'first', 'word', 'paragraph']
# Pre processed string  centre-align first word paragraph
# capitalize subscript
# ['capitalize', 'subscript']
# Pre processed string  capitalize subscript
# can you highlight all the superscript in word which you want to remove
# ['highlight', 'superscript', 'word', 'want', 'remove']
# Pre processed string  highlight superscript word want remove
# can you format it to italic
# ['format', 'italic']
# Pre processed string  format italic
# clear emphasis for the selected text
# ['clear', 'emphasis', 'selected', 'text']
# Pre processed string  clear emphasis selected text
# can you show all commants
# ['show', 'commants']
# Pre processed string  show commants
# stop dictation near the word which is bold
# ['stop', 'dictation', 'near', 'word', 'bold']
# Pre processed string  stop dictation near word bold
# can you please make it bold
# ['make', 'bold']
# Pre processed string  make bold
# please remove formatting from selected paragraph
# ['remove', 'formatting', 'selected', 'paragraph']
# Pre processed string  remove formatting selected paragraph
# please bold last word
# ['bold', 'last', 'word']
# Pre processed string  bold last word
# please pause dictation near bold text
# ['pause', 'dictation', 'near', 'bold', 'text']
# Pre processed string  pause dictation near bold text
# can you show help
# ['show', 'help']
# Pre processed string  show help
# remove strikethrough
# ['remove', 'strikethrough']
# Pre processed string  remove strikethrough
# please stop dictation near bold text
# ['stop', 'dictation', 'near', 'bold', 'text']
# Pre processed string  stop dictation near bold text
# please emphasize the selected text
# ['emphasize', 'selected', 'text']
# Pre processed string  emphasize selected text
# please move the line to the left
# ['move', 'line', 'left']
# Pre processed string  move line left
# redo the underline removed part
# ['redo', 'underline', 'removed', 'part']
# Pre processed string  redo underline removed part
# remove formatting of last letter
# ['remove', 'formatting', 'last', 'letter']
# Pre processed string  remove formatting last letter
# click the cursor to position to remove superscript
# ['click', 'cursor', 'position', 'remove', 'superscript']
# Pre processed string  click cursor position remove superscript
# can you centre-align the line
# ['centre-align', 'line']
# Pre processed string  centre-align line
# remove subscript please
# ['remove', 'subscript']
# Pre processed string  remove subscript
# please undo last paragraph
# ['undo', 'last', 'paragraph']
# Pre processed string  undo last paragraph
# can you please superscript that
# ['superscript']
# Pre processed string  superscript
# please unbold
# ['unbold']
# Pre processed string  unbold
# can you please end bullet
# ['end', 'bullet']
# Pre processed string  end bullet
# change subscript formatingstyle
# ['change', 'subscript', 'formatingstyle']
# Pre processed string  change subscript formatingstyle
# superscript last two character
# ['superscript', 'last', 'two', 'character']
# Pre processed string  superscript last two character
# can you change the selected text to italic
# ['change', 'selected', 'text', 'italic']
# Pre processed string  change selected text italic
# can you stop dictation near underlined word
# ['stop', 'dictation', 'near', 'underlined', 'word']
# Pre processed string  stop dictation near underlined word
# please remove strikethrough
# ['remove', 'strikethrough']
# Pre processed string  remove strikethrough
# change the text to bold
# ['change', 'text', 'bold']
# Pre processed string  change text bold
# can you please undo
# ['undo']
# Pre processed string  undo
# please unitalicize the selected text
# ['unitalicize', 'selected', 'text']
# Pre processed string  unitalicize selected text
# kindly go to next bullet
# ['go', 'next', 'bullet']
# Pre processed string  go next bullet
# please end dictation
# ['end', 'dictation']
# Pre processed string  end dictation
# stop inserting bullet
# ['stop', 'inserting', 'bullet']
# Pre processed string  stop inserting bullet
# can you please display help ?
# ['display', 'help', '?']
# Pre processed string  display help ?
# could you please italicize that last sentence for me
# ['italicize', 'last', 'sentence']
# Pre processed string  italicize last sentence
# take a break from dictation
# ['take', 'break', 'dictation']
# Pre processed string  take break dictation
# underline subscript
# ['underline', 'subscript']
# Pre processed string  underline subscript
# clear italic from selected word
# ['clear', 'italic', 'selected', 'word']
# Pre processed string  clear italic selected word
# please stop bullet
# ['stop', 'bullet']
# Pre processed string  stop bullet
# please right align the first word of this paragraph
# ['right', 'align', 'first', 'word', 'paragraph']
# Pre processed string  right align first word paragraph
# italicize the selected text
# ['italicize', 'selected', 'text']
# Pre processed string  italicize selected text
# left align the selected paragraph
# ['left', 'align', 'selected', 'paragraph']
# Pre processed string  left align selected paragraph
# strikethrough font size
# ['strikethrough', 'font', 'size']
# Pre processed string  strikethrough font size
# right align the content
# ['right', 'align', 'content']
# Pre processed string  right align content
# remove formaating from last sentence
# ['remove', 'formaating', 'last', 'sentence']
# Pre processed string  remove formaating last sentence
# please shift the text right
# ['shift', 'text', 'right']
# Pre processed string  shift text right
# can you remove underline for that word
# ['remove', 'underline', 'word']
# Pre processed string  remove underline word
# put bullet here
# ['put', 'bullet']
# Pre processed string  put bullet
# insert bullet
# ['insert', 'bullet']
# Pre processed string  insert bullet
# please start inserting bullet
# ['start', 'inserting', 'bullet']
# Pre processed string  start inserting bullet
# please remove subscript
# ['remove', 'subscript']
# Pre processed string  remove subscript
# italicize the last four sentence
# ['italicize', 'last', 'four', 'sentence']
# Pre processed string  italicize last four sentence
# can you underline last word
# ['underline', 'last', 'word']
# Pre processed string  underline last word
# please remove formatting from the selected sentence
# ['remove', 'formatting', 'selected', 'sentence']
# Pre processed string  remove formatting selected sentence
# please delete all text in bold
# ['delete', 'text', 'bold']
# Pre processed string  delete text bold
# strikethrough textfull
# ['strikethrough', 'textfull']
# Pre processed string  strikethrough textfull
# stop dictation near underlined word
# ['stop', 'dictation', 'near', 'underlined', 'word']
# Pre processed string  stop dictation near underlined word
# remove superscript from that
# ['remove', 'superscript']
# Pre processed string  remove superscript
# please undo formatting for last page
# ['undo', 'formatting', 'last', 'page']
# Pre processed string  undo formatting last page
# can you delete last two word in line
# ['delete', 'last', 'two', 'word', 'line']
# Pre processed string  delete last two word line
# can you right align the image above
# ['right', 'align', 'image']
# Pre processed string  right align image
# move this line to the right
# ['move', 'line', 'right']
# Pre processed string  move line right
# bold subscript
# ['bold', 'subscript']
# Pre processed string  bold subscript
# please right align the table below
# ['right', 'align', 'table']
# Pre processed string  right align table
# left align the image
# ['left', 'align', 'image']
# Pre processed string  left align image
# align the table in the middle
# ['align', 'table', 'middle']
# Pre processed string  align table middle
# remove underline for selected word
# ['remove', 'underline', 'selected', 'word']
# Pre processed string  remove underline selected word
# centre align the icon
# ['centre', 'align', 'icon']
# Pre processed string  centre align icon
# remove strike for last two character
# ['remove', 'strike', 'last', 'two', 'character']
# Pre processed string  remove strike last two character
# delete that underlined text
# ['delete', 'underlined', 'text']
# Pre processed string  delete underlined text
# can you superscript symbol
# ['superscript', 'symbol']
# Pre processed string  superscript symbol
# clear italic from last sentence
# ['clear', 'italic', 'last', 'sentence']
# Pre processed string  clear italic last sentence
# delete all text in bold
# ['delete', 'text', 'bold']
# Pre processed string  delete text bold
# align the line to the left
# ['align', 'line', 'left']
# Pre processed string  align line left
# could you undo the last sentence
# ['undo', 'last', 'sentence']
# Pre processed string  undo last sentence
# remove first two character strikethrough
# ['remove', 'first', 'two', 'character', 'strikethrough']
# Pre processed string  remove first two character strikethrough
# position the image in the middle of the page
# ['position', 'image', 'middle', 'page']
# Pre processed string  position image middle page
# underline the selected word
# ['underline', 'selected', 'word']
# Pre processed string  underline selected word
# remove the superscript
# ['remove', 'superscript']
# Pre processed string  remove superscript
# can you add a comment down here
# ['add', 'comment']
# Pre processed string  add comment
# open all command
# ['open', 'command']
# Pre processed string  open command
# please undo the text
# ['undo', 'text']
# Pre processed string  undo text
# format to unitalicize for me
# ['format', 'unitalicize']
# Pre processed string  format unitalicize
# remove italic from last word
# ['remove', 'italic', 'last', 'word']
# Pre processed string  remove italic last word
# please display all command
# ['display', 'command']
# Pre processed string  display command
# remove underline for last three word
# ['remove', 'underline', 'last', 'three', 'word']
# Pre processed string  remove underline last three word
# can you strikethrough font size
# ['strikethrough', 'font', 'size']
# Pre processed string  strikethrough font size
# remove formatting from the line above
# ['remove', 'formatting', 'line']
# Pre processed string  remove formatting line
# undo strikethrough for last two character
# ['undo', 'strikethrough', 'last', 'two', 'character']
# Pre processed string  undo strikethrough last two character
# remove subscript
# ['remove', 'subscript']
# Pre processed string  remove subscript
# remove strike for first 2 character
# ['remove', 'strike', 'first', '2', 'character']
# Pre processed string  remove strike first 2 character
# remove bold for me
# ['remove', 'bold']
# Pre processed string  remove bold
# italicize that for me
# ['italicize']
# Pre processed string  italicize
# help needed
# ['help', 'needed']
# Pre processed string  help needed
# unbold the last word
# ['unbold', 'last', 'word']
# Pre processed string  unbold last word
# insert a comment below
# ['insert', 'comment']
# Pre processed string  insert comment
# please underline that
# ['underline']
# Pre processed string  underline
# please undo the selected text
# ['undo', 'selected', 'text']
# Pre processed string  undo selected text
# could you please stop bullet ?
# ['stop', 'bullet', '?']
# Pre processed string  stop bullet ?
# can you underline last three word
# ['underline', 'last', 'three', 'word']
# Pre processed string  underline last three word
# can you end bullet
# ['end', 'bullet']
# Pre processed string  end bullet
# terminate bulleted list
# ['terminate', 'bulleted', 'list']
# Pre processed string  terminate bulleted list
# please insert a comment above this line
# ['insert', 'comment', 'line']
# Pre processed string  insert comment line
# halt dictation near bold text
# ['halt', 'dictation', 'near', 'bold', 'text']
# Pre processed string  halt dictation near bold text
# centre align the table
# ['centre', 'align', 'table']
# Pre processed string  centre align table
# left align the image
# ['left', 'align', 'image']
# Pre processed string  left align image
# pause dictation near underlined word
# ['pause', 'dictation', 'near', 'underlined', 'word']
# Pre processed string  pause dictation near underlined word
# bold the last word
# ['bold', 'last', 'word']
# Pre processed string  bold last word
# undo the previous sentence
# ['undo', 'previous', 'sentence']
# Pre processed string  undo previous sentence
# please remove formatting from last character
# ['remove', 'formatting', 'last', 'character']
# Pre processed string  remove formatting last character
# show all command
# ['show', 'command']
# Pre processed string  show command
# centre align the first word of selected paragraph
# ['centre', 'align', 'first', 'word', 'selected', 'paragraph']
# Pre processed string  centre align first word selected paragraph
# please remove underline
# ['remove', 'underline']
# Pre processed string  remove underline
# can you open all command
# ['open', 'command']
# Pre processed string  open command
# unitalicized the selected text
# ['unitalicized', 'selected', 'text']
# Pre processed string  unitalicized selected text
# delete all text that is underlined
# ['delete', 'text', 'underlined']
# Pre processed string  delete text underlined
# can you please go to next bullet
# ['go', 'next', 'bullet']
# Pre processed string  go next bullet
# please underline last word
# ['underline', 'last', 'word']
# Pre processed string  underline last word
# remove superscript please
# ['remove', 'superscript']
# Pre processed string  remove superscript
# unitalicize the sentence
# ['unitalicize', 'sentence']
# Pre processed string  unitalicize sentence
# can you stop dictation near bold text
# ['stop', 'dictation', 'near', 'bold', 'text']
# Pre processed string  stop dictation near bold text
# please bold the last sentence
# ['bold', 'last', 'sentence']
# Pre processed string  bold last sentence
# right align the first word of selected paragraph
# ['right', 'align', 'first', 'word', 'selected', 'paragraph']
# Pre processed string  right align first word selected paragraph
# remove superscript from last character
# ['remove', 'superscript', 'last', 'character']
# Pre processed string  remove superscript last character
# can you show command
# ['show', 'command']
# Pre processed string  show command
# undo strikethrough
# ['undo', 'strikethrough']
# Pre processed string  undo strikethrough
# emphasize that for me
# ['emphasize']
# Pre processed string  emphasize
# right align the icon
# ['right', 'align', 'icon']
# Pre processed string  right align icon
# remove bold from that sentence
# ['remove', 'bold', 'sentence']
# Pre processed string  remove bold sentence
# please right align the table above
# ['right', 'align', 'table']
# Pre processed string  right align table
# centre align the selected paragraph
# ['centre', 'align', 'selected', 'paragraph']
# Pre processed string  centre align selected paragraph
# start inserting bullet
# ['start', 'inserting', 'bullet']
# Pre processed string  start inserting bullet
# please right align the paragraph below
# ['right', 'align', 'paragraph']
# Pre processed string  right align paragraph
# delete that italic text
# ['delete', 'italic', 'text']
# Pre processed string  delete italic text
# please stop dictation near underlined text
# ['stop', 'dictation', 'near', 'underlined', 'text']
# Pre processed string  stop dictation near underlined text
# click to position the cursor to the right of the character requiring a superscript
# ['click', 'position', 'cursor', 'right', 'character', 'requiring', 'superscript']
# Pre processed string  click position cursor right character requiring superscript
# please add a comment at this word
# ['add', 'comment', 'word']
# Pre processed string  add comment word
# please remove the formatting in the line
# ['remove', 'formatting', 'line']
# Pre processed string  remove formatting line
# place a comment below this line
# ['place', 'comment', 'line']
# Pre processed string  place comment line
# please centre align
# ['centre', 'align']
# Pre processed string  centre align
# can you highlight all the superscript in word
# ['highlight', 'superscript', 'word']
# Pre processed string  highlight superscript word
# can you right align the first word of the content
# ['right', 'align', 'first', 'word', 'content']
# Pre processed string  right align first word content
# left align the selected line
# ['left', 'align', 'selected', 'line']
# Pre processed string  left align selected line
# present all command
# ['present', 'command']
# Pre processed string  present command
# remove bold for the last two sentence
# ['remove', 'bold', 'last', 'two', 'sentence']
# Pre processed string  remove bold last two sentence
# can you make it bold for me
# ['make', 'bold']
# Pre processed string  make bold
# please italicise that
# ['italicise']
# Pre processed string  italicise
# remove all formatting from this page
# ['remove', 'formatting', 'page']
# Pre processed string  remove formatting page
# delete all text in underlined
# ['delete', 'text', 'underlined']
# Pre processed string  delete text underlined
# stop bullet
# ['stop', 'bullet']
# Pre processed string  stop bullet
# show command
# ['show', 'command']
# Pre processed string  show command
# please clear italic from last two word
# ['clear', 'italic', 'last', 'two', 'word']
# Pre processed string  clear italic last two word
# erase the last paragraph
# ['erase', 'last', 'paragraph']
# Pre processed string  erase last paragraph
# underline the last word please
# ['underline', 'last', 'word']
# Pre processed string  underline last word
# left align the last word of selected paragraph
# ['left', 'align', 'last', 'word', 'selected', 'paragraph']
# Pre processed string  left align last word selected paragraph
# remove italic from last sentence
# ['remove', 'italic', 'last', 'sentence']
# Pre processed string  remove italic last sentence
# can you underline the selected word
# ['underline', 'selected', 'word']
# Pre processed string  underline selected word
# underline that word please
# ['underline', 'word']
# Pre processed string  underline word
# remove strike for first 2 letter
# ['remove', 'strike', 'first', '2', 'letter']
# Pre processed string  remove strike first 2 letter
# you should insert bullet here
# ['insert', 'bullet']
# Pre processed string  insert bullet
# remove strikethrough for last two character
# ['remove', 'strikethrough', 'last', 'two', 'character']
# Pre processed string  remove strikethrough last two character
# can you please unbold it
# ['unbold']
# Pre processed string  unbold
# bold the last paragraph
# ['bold', 'last', 'paragraph']
# Pre processed string  bold last paragraph
# exit bullet and start new paragraph
# ['exit', 'bullet', 'start', 'new', 'paragraph']
# Pre processed string  exit bullet start new paragraph
# undo the last sentence
# ['undo', 'last', 'sentence']
# Pre processed string  undo last sentence
# please clear bold
# ['clear', 'bold']
# Pre processed string  clear bold
# emphasize the selected word
# ['emphasize', 'selected', 'word']
# Pre processed string  emphasize selected word
# delete last paragraph
# ['delete', 'last', 'paragraph']
# Pre processed string  delete last paragraph
# please add next bullet
# ['add', 'next', 'bullet']
# Pre processed string  add next bullet
# remove strike for last two character
# ['remove', 'strike', 'last', 'two', 'character']
# Pre processed string  remove strike last two character
# remove emphasis for the selected text
# ['remove', 'emphasis', 'selected', 'text']
# Pre processed string  remove emphasis selected text
# please erase all text
# ['erase', 'text']
# Pre processed string  erase text
# please undo for me
# ['undo']
# Pre processed string  undo
# open command
# ['open', 'command']
# Pre processed string  open command
# please exit from list
# ['exit', 'list']
# Pre processed string  exit list
# please italicise the last two word
# ['italicise', 'last', 'two', 'word']
# Pre processed string  italicise last two word
# last two word underline
# ['last', 'two', 'word', 'underline']
# Pre processed string  last two word underline
# italicize that last two sentence
# ['italicize', 'last', 'two', 'sentence']
# Pre processed string  italicize last two sentence
# please pause dictation near underlined word
# ['pause', 'dictation', 'near', 'underlined', 'word']
# Pre processed string  pause dictation near underlined word
# delete last two line of paragraph
# ['delete', 'last', 'two', 'line', 'paragraph']
# Pre processed string  delete last two line paragraph
# please italicise the selected text
# ['italicise', 'selected', 'text']
# Pre processed string  italicise selected text
# please strikethrough text
# ['strikethrough', 'text']
# Pre processed string  strikethrough text
# centre align the selected line
# ['centre', 'align', 'selected', 'line']
# Pre processed string  centre align selected line
# can you please open all command ?
# ['open', 'command', '?']
# Pre processed string  open command ?
# start next bullet
# ['start', 'next', 'bullet']
# Pre processed string  start next bullet
# can you centre-align the sentence
# ['centre-align', 'sentence']
# Pre processed string  centre-align sentence
# capitalize last two character in subscript
# ['capitalize', 'last', 'two', 'character', 'subscript']
# Pre processed string  capitalize last two character subscript
# please end bullet from the selected line
# ['end', 'bullet', 'selected', 'line']
# Pre processed string  end bullet selected line
# centre the content
# ['centre', 'content']
# Pre processed string  centre content
# unbold that for me
# ['unbold']
# Pre processed string  unbold
# strikethrough last two character
# ['strikethrough', 'last', 'two', 'character']
# Pre processed string  strikethrough last two character
# remove last word formatting
# ['remove', 'last', 'word', 'formatting']
# Pre processed string  remove last word formatting
# please open all command
# ['open', 'command']
# Pre processed string  open command
# can you please delete the selected text ?
# ['delete', 'selected', 'text', '?']
# Pre processed string  delete selected text ?
# add next bullet
# ['add', 'next', 'bullet']
# Pre processed string  add next bullet
# can you insert a comment here
# ['insert', 'comment']
# Pre processed string  insert comment
# stop dictation near the word which is bold and underlined
# ['stop', 'dictation', 'near', 'word', 'bold', 'underlined']
# Pre processed string  stop dictation near word bold underlined
# please display help
# ['display', 'help']
# Pre processed string  display help
# please insert bullet
# ['insert', 'bullet']
# Pre processed string  insert bullet
# pause dictation near the word which is bold
# ['pause', 'dictation', 'near', 'word', 'bold']
# Pre processed string  pause dictation near word bold
# position it in the middle
# ['position', 'middle']
# Pre processed string  position middle
# can you pause dictation near underlined word
# ['pause', 'dictation', 'near', 'underlined', 'word']
# Pre processed string  pause dictation near underlined word
# superscript that please
# ['superscript']
# Pre processed string  superscript
# let 's stop dictation now
# ['let', "'s", 'stop', 'dictation']
# Pre processed string  let 's stop dictation
# will you undo the text for me
# ['undo', 'text']
# Pre processed string  undo text
# can you undo the last sentence
# ['undo', 'last', 'sentence']
# Pre processed string  undo last sentence
# show help
# ['show', 'help']
# Pre processed string  show help
# please undo strikethrough
# ['undo', 'strikethrough']
# Pre processed string  undo strikethrough
# please undo the selected word
# ['undo', 'selected', 'word']
# Pre processed string  undo selected word
# bold that for me
# ['bold']
# Pre processed string  bold
# please remove bold
# ['remove', 'bold']
# Pre processed string  remove bold
# can you make it underline for me
# ['make', 'underline']
# Pre processed string  make underline
# unbold for me
# ['unbold']
# Pre processed string  unbold
# please remove formatting form last word
# ['remove', 'formatting', 'form', 'last', 'word']
# Pre processed string  remove formatting form last word
# strikethrough underline style
# ['strikethrough', 'underline', 'style']
# Pre processed string  strikethrough underline style
# please format the text to bold
# ['format', 'text', 'bold']
# Pre processed string  format text bold
# insert comment on last line
# ['insert', 'comment', 'last', 'line']
# Pre processed string  insert comment last line
# can you please format to italic
# ['format', 'italic']
# Pre processed string  format italic
# clear bold for last two sentence
# ['clear', 'bold', 'last', 'two', 'sentence']
# Pre processed string  clear bold last two sentence
# clear bold for me
# ['clear', 'bold']
# Pre processed string  clear bold
# please pause dictation
# ['pause', 'dictation']
# Pre processed string  pause dictation
# undo the last word
# ['undo', 'last', 'word']
# Pre processed string  undo last word
# please italicize that
# ['italicize']
# Pre processed string  italicize
# please insert bullet for line in this paragraph
# ['insert', 'bullet', 'line', 'paragraph']
# Pre processed string  insert bullet line paragraph
# could you undo that for me
# ['undo']
# Pre processed string  undo
# strikethrouhgh font size please
# ['strikethrouhgh', 'font', 'size']
# Pre processed string  strikethrouhgh font size
# remove formatting above
# ['remove', 'formatting']
# Pre processed string  remove formatting
# remove strikethrough for last two character
# ['remove', 'strikethrough', 'last', 'two', 'character']
# Pre processed string  remove strikethrough last two character
# can you remove superscript from last two character
# ['remove', 'superscript', 'last', 'two', 'character']
# Pre processed string  remove superscript last two character
# stop dictation near the word which is underlined
# ['stop', 'dictation', 'near', 'word', 'underlined']
# Pre processed string  stop dictation near word underlined
# insert comment on the last line
# ['insert', 'comment', 'last', 'line']
# Pre processed string  insert comment last line
# please insert a comment on this word
# ['insert', 'comment', 'word']
# Pre processed string  insert comment word
# please halt dictation
# ['halt', 'dictation']
# Pre processed string  halt dictation
# please stop dictation
# ['stop', 'dictation']
# Pre processed string  stop dictation
# please underline that for me
# ['underline']
# Pre processed string  underline
# please show all command
# ['show', 'command']
# Pre processed string  show command
# remove formatting from the sentence below
# ['remove', 'formatting', 'sentence']
# Pre processed string  remove formatting sentence
# left align the icon
# ['left', 'align', 'icon']
# Pre processed string  left align icon
# delete all text
# ['delete', 'text']
# Pre processed string  delete text
# bold last n word in subscript
# ['bold', 'last', 'n', 'word', 'subscript']
# Pre processed string  bold last n word subscript
# reveal all command
# ['reveal', 'command']
# Pre processed string  reveal command
# undo strikethrough for first 2 character
# ['undo', 'strikethrough', 'first', '2', 'character']
# Pre processed string  undo strikethrough first 2 character
# position the table in the middle
# ['position', 'table', 'middle']
# Pre processed string  position table middle
# could you underline that
# ['underline']
# Pre processed string  underline
# please insert bullet for the selected sentence
# ['insert', 'bullet', 'selected', 'sentence']
# Pre processed string  insert bullet selected sentence
# insert comment on the selected line
# ['insert', 'comment', 'selected', 'line']
# Pre processed string  insert comment selected line
# can you please start inserting bullet for selected paragraph
# ['start', 'inserting', 'bullet', 'selected', 'paragraph']
# Pre processed string  start inserting bullet selected paragraph
# please start next bullet
# ['start', 'next', 'bullet']
# Pre processed string  start next bullet
# please undo the change
# ['undo', 'change']
# Pre processed string  undo change
# display all command
# ['display', 'command']
# Pre processed string  display command
# please superscript that
# ['superscript']
# Pre processed string  superscript
# delete last two word of line
# ['delete', 'last', 'two', 'word', 'line']
# Pre processed string  delete last two word line
# can you stop dictation
# ['stop', 'dictation']
# Pre processed string  stop dictation
# please show help
# ['show', 'help']
# Pre processed string  show help
# can you pause dictation
# ['pause', 'dictation']
# Pre processed string  pause dictation
# left align the first word of selected paragraph
# ['left', 'align', 'first', 'word', 'selected', 'paragraph']
# Pre processed string  left align first word selected paragraph
# can you start next bullet after this line
# ['start', 'next', 'bullet', 'line']
# Pre processed string  start next bullet line
# right align the last word of selected paragraph
# ['right', 'align', 'last', 'word', 'selected', 'paragraph']
# Pre processed string  right align last word selected paragraph
# remove the formatting from this sentence
# ['remove', 'formatting', 'sentence']
# Pre processed string  remove formatting sentence
# delete all the text in underlined
# ['delete', 'text', 'underlined']
# Pre processed string  delete text underlined
# please undo
# ['undo']
# Pre processed string  undo
# please increase subscript fontsize
# ['increase', 'subscript', 'fontsize']
# Pre processed string  increase subscript fontsize
# make the selected word underline
# ['make', 'selected', 'word', 'underline']
# Pre processed string  make selected word underline
# remove second character in subscript
# ['remove', 'second', 'character', 'subscript']
# Pre processed string  remove second character subscript
# please make it bold
# ['make', 'bold']
# Pre processed string  make bold
# make the selected word bold
# ['make', 'selected', 'word', 'bold']
# Pre processed string  make selected word bold
# position the table in the middle
# ['position', 'table', 'middle']
# Pre processed string  position table middle
# underline the last word
# ['underline', 'last', 'word']
# Pre processed string  underline last word
# can you bold subscript
# ['bold', 'subscript']
# Pre processed string  bold subscript
# what command are there ?
# ['command', '?']
# Pre processed string  command ?
# make it underline
# ['make', 'underline']
# Pre processed string  make underline
# remove underline for the last two character
# ['remove', 'underline', 'last', 'two', 'character']
# Pre processed string  remove underline last two character
# kindly display help
# ['display', 'help']
# Pre processed string  display help
# help me
# ['help']
# Pre processed string  help
# please left align the content
# ['left', 'align', 'content']
# Pre processed string  left align content
# please remove subscript
# ['remove', 'subscript']
# Pre processed string  remove subscript
# please insert bullet for line on this page
# ['insert', 'bullet', 'line', 'page']
# Pre processed string  insert bullet line page
# last word underline
# ['last', 'word', 'underline']
# Pre processed string  last word underline
# clear the italic for me
# ['clear', 'italic']
# Pre processed string  clear italic
# please remove formatting from this page
# ['remove', 'formatting', 'page']
# Pre processed string  remove formatting page
# remove last two character strikethrough
# ['remove', 'last', 'two', 'character', 'strikethrough']
# Pre processed string  remove last two character strikethrough
# unbold the selected text
# ['unbold', 'selected', 'text']
# Pre processed string  unbold selected text
# please end bullet
# ['end', 'bullet']
# Pre processed string  end bullet
# insert comment on italic word
# ['insert', 'comment', 'italic', 'word']
# Pre processed string  insert comment italic word
# delete that bold text
# ['delete', 'bold', 'text']
# Pre processed string  delete bold text
# strikethrough first two character
# ['strikethrough', 'first', 'two', 'character']
# Pre processed string  strikethrough first two character
# right align the selected paragraph
# ['right', 'align', 'selected', 'paragraph']
# Pre processed string  right align selected paragraph
# end dictation
# ['end', 'dictation']
# Pre processed string  end dictation
# strikethrough textoutline
# ['strikethrough', 'textoutline']
# Pre processed string  strikethrough textoutline
# can you italicize that sentence
# ['italicize', 'sentence']
# Pre processed string  italicize sentence
# change the selected text to italic
# ['change', 'selected', 'text', 'italic']
# Pre processed string  change selected text italic
# halt dictation here
# ['halt', 'dictation']
# Pre processed string  halt dictation
# centre align the last word of selected paragraph
# ['centre', 'align', 'last', 'word', 'selected', 'paragraph']
# Pre processed string  centre align last word selected paragraph
# help required
# ['help', 'required']
# Pre processed string  help required
# could you undo the selected text
# ['undo', 'selected', 'text']
# Pre processed string  undo selected text
# can you please show all command ?
# ['show', 'command', '?']
# Pre processed string  show command ?
# remove strike
# ['remove', 'strike']
# Pre processed string  remove strike
# can you remove formatting from the last 3 line
# ['remove', 'formatting', 'last', '3', 'line']
# Pre processed string  remove formatting last 3 line
# capitalize first two character in subscript
# ['capitalize', 'first', 'two', 'character', 'subscript']
# Pre processed string  capitalize first two character subscript
# can you strikethrouh text please
# ['strikethrouh', 'text']
# Pre processed string  strikethrouh text
# can you remove formatting
# ['remove', 'formatting']
# Pre processed string  remove formatting
# strikethrouhgh text
# ['strikethrouhgh', 'text']
# Pre processed string  strikethrouhgh text
# could you please stop dictation ?
# ['stop', 'dictation', '?']
# Pre processed string  stop dictation ?
# please delete the selected text
# ['delete', 'selected', 'text']
# Pre processed string  delete selected text
# remove formatting from 5 line above
# ['remove', 'formatting', '5', 'line']
# Pre processed string  remove formatting 5 line
# strikethrough font
# ['strikethrough', 'font']
# Pre processed string  strikethrough font
# selected text should be deleted
# ['selected', 'text', 'deleted']
# Pre processed string  selected text deleted
# type the character for the superscript
# ['type', 'character', 'superscript']
# Pre processed string  type character superscript
# centre align the picture
# ['centre', 'align', 'picture']
# Pre processed string  centre align picture
# remove bold for the selected text
# ['remove', 'bold', 'selected', 'text']
# Pre processed string  remove bold selected text
# move the text to the left
# ['move', 'text', 'left']
# Pre processed string  move text left
# remove strikethrough for first 2 character
# ['remove', 'strikethrough', 'first', '2', 'character']
# Pre processed string  remove strikethrough first 2 character
# can you please stop dictation near underlined text
# ['stop', 'dictation', 'near', 'underlined', 'text']
# Pre processed string  stop dictation near underlined text
# format the selected text to italic
# ['format', 'selected', 'text', 'italic']
# Pre processed string  format selected text italic
# centre align the image
# ['centre', 'align', 'image']
# Pre processed string  centre align image
# erase the last two word of that sentence
# ['erase', 'last', 'two', 'word', 'sentence']
# Pre processed string  erase last two word sentence
# display a list of command
# ['display', 'list', 'command']
# Pre processed string  display list command
# can you remove underline for me
# ['remove', 'underline']
# Pre processed string  remove underline
# select the text or number that you want to superscript
# ['select', 'text', 'number', 'want', 'superscript']
# Pre processed string  select text number want superscript
# can you remove formatting from this paragraph
# ['remove', 'formatting', 'paragraph']
# Pre processed string  remove formatting paragraph
# add bullet here
# ['add', 'bullet']
# Pre processed string  add bullet
# format to emphasize the selected text
# ['format', 'emphasize', 'selected', 'text']
# Pre processed string  format emphasize selected text
# could you please delete last two word in line ?
# ['delete', 'last', 'two', 'word', 'line', '?']
# Pre processed string  delete last two word line ?
# underline first n word in subscript
# ['underline', 'first', 'n', 'word', 'subscript']
# Pre processed string  underline first n word subscript
# remove italic for me
# ['remove', 'italic']
# Pre processed string  remove italic
# bold the last two word
# ['bold', 'last', 'two', 'word']
# Pre processed string  bold last two word
# can you remove the superscript
# ['remove', 'superscript']
# Pre processed string  remove superscript
# what command are present
# ['command', 'present']
# Pre processed string  command present
# please clear the italic sentence
# ['clear', 'italic', 'sentence']
# Pre processed string  clear italic sentence
# go to next bullet
# ['go', 'next', 'bullet']
# Pre processed string  go next bullet
# please pause dictation near underlined text
# ['pause', 'dictation', 'near', 'underlined', 'text']
# Pre processed string  pause dictation near underlined text
# clear page of formatting
# ['clear', 'page', 'formatting']
# Pre processed string  clear page formatting
# underline please
# ['underline']
# Pre processed string  underline
# remove emphasis for the last sentence
# ['remove', 'emphasis', 'last', 'sentence']
# Pre processed string  remove emphasis last sentence
# remove supescript for all word with font red
# ['remove', 'supescript', 'word', 'font', 'red']
# Pre processed string  remove supescript word font red
# left align the table
# ['left', 'align', 'table']
# Pre processed string  left align table
# open help
# ['open', 'help']
# Pre processed string  open help
# pause dictation near the word which is underlined
# ['pause', 'dictation', 'near', 'word', 'underlined']
# Pre processed string  pause dictation near word underlined
# can you undo formatting from last word
# ['undo', 'formatting', 'last', 'word']
# Pre processed string  undo formatting last word
# emphasize the last word
# ['emphasize', 'last', 'word']
# Pre processed string  emphasize last word
# please align in the middle
# ['align', 'middle']
# Pre processed string  align middle
# stop dictation
# ['stop', 'dictation']
# Pre processed string  stop dictation
# please undo strikethrough for last two character
# ['undo', 'strikethrough', 'last', 'two', 'character']
# Pre processed string  undo strikethrough last two character
# can you centr-align the last word of the paragraph
# ['centr-align', 'last', 'word', 'paragraph']
# Pre processed string  centr-align last word paragraph
# can you insert bullet
# ['insert', 'bullet']
# Pre processed string  insert bullet
# can you end bullet here
# ['end', 'bullet']
# Pre processed string  end bullet
# select the text or number that you want to remove superscript
# ['select', 'text', 'number', 'want', 'remove', 'superscript']
# Pre processed string  select text number want remove superscript
# end bullet
# ['end', 'bullet']
# Pre processed string  end bullet
# right align the table
# ['right', 'align', 'table']
# Pre processed string  right align table
# can you right align the paragraph above
# ['right', 'align', 'paragraph']
# Pre processed string  right align paragraph
# superscript that
# ['superscript']
# Pre processed string  superscript
# insert a comment above this paragraph
# ['insert', 'comment', 'paragraph']
# Pre processed string  insert comment paragraph
# pause dictation near bold text
# ['pause', 'dictation', 'near', 'bold', 'text']
# Pre processed string  pause dictation near bold text
# underline the last three word
# ['underline', 'last', 'three', 'word']
# Pre processed string  underline last three word
# unitalicized that first sentence
# ['unitalicized', 'first', 'sentence']
# Pre processed string  unitalicized first sentence
# can you please remove formatting from last 2 line
# ['remove', 'formatting', 'last', '2', 'line']
# Pre processed string  remove formatting last 2 line
# remove last two character in subscript
# ['remove', 'last', 'two', 'character', 'subscript']
# Pre processed string  remove last two character subscript
# pause dictation near the word which is bold and underlined
# ['pause', 'dictation', 'near', 'word', 'bold', 'underlined']
# Pre processed string  pause dictation near word bold underlined
# insert comment of first line
# ['insert', 'comment', 'first', 'line']
# Pre processed string  insert comment first line
# put next bullet here
# ['put', 'next', 'bullet']
# Pre processed string  put next bullet
# can you left align this paragraph
# ['left', 'align', 'paragraph']
# Pre processed string  left align paragraph
# delete subscript
# ['delete', 'subscript']
# Pre processed string  delete subscript
# insert bullet for line in this paragraph
# ['insert', 'bullet', 'line', 'paragraph']
# Pre processed string  insert bullet line paragraph
# please open command
# ['open', 'command']
# Pre processed string  open command
# insert bullet here
# ['insert', 'bullet']
# Pre processed string  insert bullet
# pause dictation
# ['pause', 'dictation']
# Pre processed string  pause dictation
# move this paragraph to the right
# ['move', 'paragraph', 'right']
# Pre processed string  move paragraph right
# insert comment on start if new paragraph
# ['insert', 'comment', 'start', 'new', 'paragraph']
# Pre processed string  insert comment start new paragraph
# please go to next bullet
# ['go', 'next', 'bullet']
# Pre processed string  go next bullet
# format to bold for me
# ['format', 'bold']
# Pre processed string  format bold
# please show command
# ['show', 'command']
# Pre processed string  show command
# kindly present all command
# ['present', 'command']
# Pre processed string  present command
# strikethrough fontstyle
# ['strikethrough', 'fontstyle']
# Pre processed string  strikethrough fontstyle
# stop dictation near bold text
# ['stop', 'dictation', 'near', 'bold', 'text']
# Pre processed string  stop dictation near bold text
# delete selected line
# ['delete', 'selected', 'line']
# Pre processed string  delete selected line
# please make the selected text to italic
# ['make', 'selected', 'text', 'italic']
# Pre processed string  make selected text italic
# remove two character strikethrough
# ['remove', 'two', 'character', 'strikethrough']
# Pre processed string  remove two character strikethrough
# remove underline for that sentence
# ['remove', 'underline', 'sentence']
# Pre processed string  remove underline sentence
# can you bold the selected text
# ['bold', 'selected', 'text']
# Pre processed string  bold selected text
# please open help
# ['open', 'help']
# Pre processed string  open help
# can you please clear italic
# ['clear', 'italic']
# Pre processed string  clear italic
# will you italicise that for me
# ['italicise']
# Pre processed string  italicise
# can you start from next bullet
# ['start', 'next', 'bullet']
# Pre processed string  start next bullet
# insert a superscript symbol
# ['insert', 'superscript', 'symbol']
# Pre processed string  insert superscript symbol
# please remove the italic sentence
# ['remove', 'italic', 'sentence']
# Pre processed string  remove italic sentence
# could you undo the change
# ['undo', 'change']
# Pre processed string  undo change
# remove superscript from last two character
# ['remove', 'superscript', 'last', 'two', 'character']
# Pre processed string  remove superscript last two character
# remove first two character in subscript
# ['remove', 'first', 'two', 'character', 'subscript']
# Pre processed string  remove first two character subscript
# underline the last two character
# ['underline', 'last', 'two', 'character']
# Pre processed string  underline last two character
# can you pause dictation near bold text
# ['pause', 'dictation', 'near', 'bold', 'text']
# Pre processed string  pause dictation near bold text
# remove underline for all the word in red color
# ['remove', 'underline', 'word', 'red', 'color']
# Pre processed string  remove underline word red color
# please remove superscript
# ['remove', 'superscript']
# Pre processed string  remove superscript
# right align the selected line
# ['right', 'align', 'selected', 'line']
# Pre processed string  right align selected line
# right align the image
# ['right', 'align', 'image']
# Pre processed string  right align image
# underline that
# ['underline']
# Pre processed string  underline
# please underline the last three word
# ['underline', 'last', 'three', 'word']
# Pre processed string  underline last three word
# stop dictation near the word in bold
# ['stop', 'dictation', 'near', 'word', 'bold']
# Pre processed string  stop dictation near word bold
# please stop dictation near the bold word
# ['stop', 'dictation', 'near', 'bold', 'word']
# Pre processed string  stop dictation near bold word
# kindly delete all text in bold
# ['delete', 'text', 'bold']
# Pre processed string  delete text bold
# please underline the selected word
# ['underline', 'selected', 'word']
# Pre processed string  underline selected word
# place the paragraph in the middle
# ['place', 'paragraph', 'middle']
# Pre processed string  place paragraph middle
# display help
# ['display', 'help']
# Pre processed string  display help
# underline that selected text
# ['underline', 'selected', 'text']
# Pre processed string  underline selected text
# remove underline please
# ['remove', 'underline']
# Pre processed string  remove underline
# please undo strikethrough for first 2 character
# ['undo', 'strikethrough', 'first', '2', 'character']
# Pre processed string  undo strikethrough first 2 character
# kindly delete the last paragraph
# ['delete', 'last', 'paragraph']
# Pre processed string  delete last paragraph
# delete last two word in paragraph
# ['delete', 'last', 'two', 'word', 'paragraph']
# Pre processed string  delete last two word paragraph
# please undo strikethrough for last two character
# ['undo', 'strikethrough', 'last', 'two', 'character']
# Pre processed string  undo strikethrough last two character
# undo strikethrough for last two character
# ['undo', 'strikethrough', 'last', 'two', 'character']
# Pre processed string  undo strikethrough last two character
# underline last n word in subscript
# ['underline', 'last', 'n', 'word', 'subscript']
# Pre processed string  underline last n word subscript
# decrease subscript fontsize
# ['decrease', 'subscript', 'fontsize']
# Pre processed string  decrease subscript fontsize
# move to next bullet
# ['move', 'next', 'bullet']
# Pre processed string  move next bullet
# please take a break from dictation
# ['take', 'break', 'dictation']
# Pre processed string  take break dictation
# shift the paragraph to the middlwe
# ['shift', 'paragraph', 'middlwe']
# Pre processed string  shift paragraph middlwe
# can you open help
# ['open', 'help']
# Pre processed string  open help
# please stop dictation near underlined word
# ['stop', 'dictation', 'near', 'underlined', 'word']
# Pre processed string  stop dictation near underlined word
# align the table in the middle
# ['align', 'table', 'middle']
# Pre processed string  align table middle

# %%
vocab_size = 1000
embedding_dim = 20
max_length = 10
trunc_type = 'post'
padding_type = 'post'
oov_tok = '<OOV>'
training_portion = 0.8

# %%
train_size = int(428*training_portion)
X=np.array(df_shuffled['INTENT'].to_list())
Y_arr=np.array(df_shuffled['ID'].to_list())
Y=[]
for val in Y_arr:
    d=[val]
    Y.append(d)
    
train_X = X[0: train_size]
train_Y = Y[0: train_size]

validation_X = X[train_size:]
validation_Y = Y[train_size:]

print(train_size)
print(len(train_X))
print(len(train_Y))
print(train_Y)
print(len(validation_X))
print(len(validation_Y))
# Out:
# 342
# 342
# 342
# [[6], [18], [26], [1], [6], [6], [15], [17], [14], [10], [9], [4], [3], [24], [23], [2], [18], [2], [22], [25], [13], [23], [2], [16], [7], [18], [9], [14], [11], [1], [8], [3], [21], [10], [8], [4], [23], [13], [2], [1], [5], [20], [23], [21], [25], [4], [22], [11], [5], [21], [17], [4], [16], [12], [17], [18], [17], [7], [19], [19], [19], [11], [4], [6], [18], [26], [12], [23], [9], [18], [26], [17], [17], [11], [17], [16], [14], [7], [14], [13], [26], [8], [5], [26], [16], [1], [13], [14], [6], [9], [15], [24], [1], [5], [5], [24], [7], [12], [18], [13], [11], [13], [3], [4], [25], [3], [15], [6], [1], [21], [6], [21], [21], [15], [22], [14], [16], [22], [2], [1], [18], [24], [14], [7], [24], [5], [26], [20], [6], [9], [5], [23], [2], [17], [9], [24], [13], [2], [17], [3], [17], [14], [19], [17], [26], [23], [8], [15], [18], [15], [14], [8], [17], [16], [24], [3], [2], [4], [18], [26], [21], [24], [5], [26], [6], [16], [5], [6], [6], [13], [19], [13], [3], [2], [21], [1], [3], [2], [26], [20], [13], [3], [26], [1], [24], [21], [4], [6], [4], [22], [26], [4], [12], [14], [24], [20], [14], [10], [21], [14], [3], [12], [18], [24], [26], [20], [15], [23], [25], [19], [22], [14], [22], [8], [23], [1], [1], [25], [13], [1], [2], [3], [6], [3], [18], [12], [2], [15], [4], [3], [3], [22], [1], [4], [19], [1], [12], [18], [13], [9], [23], [15], [15], [22], [23], [6], [24], [18], [16], [26], [10], [24], [13], [14], [6], [19], [15], [19], [20], [1], [24], [8], [26], [23], [25], [22], [16], [20], [17], [18], [26], [1], [10], [6], [11], [2], [2], [14], [6], [11], [24], [6], [7], [25], [25], [16], [11], [19], [6], [5], [18], [13], [3], [21], [15], [26], [12], [17], [23], [12], [4], [4], [22], [14], [25], [1], [24], [13], [18], [10], [12], [18], [12], [23], [26], [18], [12], [26], [8], [14], [3], [16], [13], [23], [4], [14], [26], [24], [7], [8], [18], [19], [2], [26], [10], [5], [2], [9], [24], [5], [20], [22]]
# 86
# 86

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_X)
word_index = tokenizer.word_index
dict(list(word_index.items())[0:10])
# Out:
# {'<OOV>': 1,
#  'last': 2,
#  'remove': 3,
#  'word': 4,
#  'text': 5,
#  'selected': 6,
#  'bold': 7,
#  'align': 8,
#  'underline': 9,
#  'bullet': 10}

# %%
train_sequences = tokenizer.texts_to_sequences(train_X)
print(train_sequences[1])
# Out:
# [3, 19]

# %%
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(len(train_sequences[0]))
print(len(train_padded[0]))

print(len(train_sequences[1]))
print(len(train_padded[1]))

print(len(train_sequences[10]))
print(len(train_padded[10]))
# Out:
# 2
# 10
# 2
# 10
# 5
# 10

# %%
validation_sequences = tokenizer.texts_to_sequences(validation_X)
validation_padded = pad_sequences(validation_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

print(len(validation_sequences))
print(validation_padded.shape)
# Out:
# 86
# (86, 10)

# %%
validation_Y=np.array(validation_Y)
training_Y=np.array(train_Y)
print(validation_Y.shape)
print(training_Y.shape)
# Out:
# (86, 1)
# (342, 1)

# %%
model = tf.keras.Sequential([
    # Add an Embedding layer expecting input vocab of size 5000, and output embedding dimension of size 64 we set at the top
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=10),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)),
#    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
#     use ReLU in place of tanh function since they are very good alternatives of each other.
#     tf.keras.layers.Dense(embedding_dim, activation='relu'),
    # Add a Dense layer with 27(26+0) units and softmax activation.
    # When we have multiple outputs, softmax convert outputs layers into a probability distribution.
    tf.keras.layers.Dense(27, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 10, 20)            20000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 40)                6560
# _________________________________________________________________
# dense (Dense)                (None, 27)                1107
# =================================================================
# Total params: 27,667
# Trainable params: 27,667
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
num_epochs =150
history = model.fit(train_padded, training_Y, epochs=num_epochs, validation_data=(validation_padded, validation_Y), verbose=2)
# Out:
# Train on 342 samples, validate on 86 samples
# Epoch 1/150
# 342/342 - 4s - loss: 0.2068 - acc: 0.9971 - val_loss: 0.3930 - val_acc: 0.9419
# Epoch 2/150
# 342/342 - 0s - loss: 0.1927 - acc: 0.9971 - val_loss: 0.3763 - val_acc: 0.9302
# Epoch 3/150
# 342/342 - 0s - loss: 0.1813 - acc: 0.9971 - val_loss: 0.3710 - val_acc: 0.9302
# Epoch 4/150
# 342/342 - 0s - loss: 0.1731 - acc: 0.9971 - val_loss: 0.3665 - val_acc: 0.9419
# Epoch 148/150
# 342/342 - 0s - loss: 0.0056 - acc: 1.0000 - val_loss: 0.2505 - val_acc: 0.9186
# Epoch 149/150
# 342/342 - 0s - loss: 0.0055 - acc: 1.0000 - val_loss: 0.2523 - val_acc: 0.9186
# Epoch 150/150
# 342/342 - 0s - loss: 0.0054 - acc: 1.0000 - val_loss: 0.2531 - val_acc: 0.9186

# %%
accr = model.evaluate(validation_padded,validation_Y)
# print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# 86/86 [==============================] - 0s 245us/sample - loss: 0.2531 - acc: 0.9186

# %%
import tensorflow.keras as keras

tf.keras.models.save_model(model,"weights/convert2")

# %%
new_model = tf.keras.models.load_model('weights/relu_tensor1')

# %%
import coremltools
coreml_model = coremltools.converters.keras.convert(new_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-f3e79d170285> in <module>
#       1 import coremltools
# ----> 2 coreml_model = coremltools.converters.keras.convert(new_model)
#
# ~/anaconda3/lib/python3.7/site-packages/coremltools/converters/keras/_keras_converter.py in convert(model, input_names, output_names, image_input_names, input_name_shape_dict, is_bgr, red_bias, green_bias, blue_bias, gray_bias, image_scale, class_labels, predicted_feature_name, model_precision, predicted_probabilities_output, add_custom_layers, custom_conversion_functions, input_shapes, output_shapes, respect_trainable, use_float_arraytype)
#     801                          output_shapes=output_shapes,
#     802                          respect_trainable=respect_trainable,
# --> 803                          use_float_arraytype=use_float_arraytype)
#     804
#     805     return _MLModel(spec)
#
# ~/anaconda3/lib/python3.7/site-packages/coremltools/converters/keras/_keras_converter.py in convertToSpec(model, input_names, output_names, image_input_names, input_name_shape_dict, is_bgr, red_bias, green_bias, blue_bias, gray_bias, image_scale, class_labels, predicted_feature_name, model_precision, predicted_probabilities_output, add_custom_layers, custom_conversion_functions, custom_objects, input_shapes, output_shapes, respect_trainable, use_float_arraytype)
#     582                                           output_shapes=output_shapes,
#     583                                           respect_trainable=respect_trainable,
# --> 584                                           use_float_arraytype=use_float_arraytype)
#     585     else:
#     586         raise RuntimeError(
#
# ~/anaconda3/lib/python3.7/site-packages/coremltools/converters/keras/_keras2_converter.py in _convert(model, input_names, output_names, image_input_names, input_name_shape_dict, is_bgr, red_bias, green_bias, blue_bias, gray_bias, image_scale, class_labels, predicted_feature_name, predicted_probabilities_output, add_custom_layers, custom_conversion_functions, custom_objects, input_shapes, output_shapes, respect_trainable, use_float_arraytype)
#     322
#     323     # Check valid versions
# --> 324     _check_unsupported_layers(model, add_custom_layers)
#     325
#     326     # Build network graph to represent Keras model
#
# ~/anaconda3/lib/python3.7/site-packages/coremltools/converters/keras/_keras2_converter.py in _check_unsupported_layers(model, add_custom_layers)
#     124         else:
#     125             if type(layer) not in _KERAS_LAYER_REGISTRY:
# --> 126                 raise ValueError("Keras layer '%s' not supported. " % str(type(layer)))
#     127             if isinstance(layer, _keras.layers.wrappers.TimeDistributed):
#     128                 if type(layer.layer) not in _KERAS_LAYER_REGISTRY:
#
# ValueError: Keras layer '<class 'tensorflow.python.keras.layers.embeddings.Embedding'>' not supported.
